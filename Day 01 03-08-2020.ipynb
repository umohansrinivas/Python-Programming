# %% [markdown]
# # Python Programming
# ## Day 1: 03-08-2020 (Monday)
#
# ### Agenda
# - Python Instroduction
# - Python Installation
#     - markdown format
# - Keywords in Python
# - Variables and Operators in Python

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
#
# - *Style1* - Italic
# - **Style 2** - Bold
# - ***Style3*** - Bold and Italic

# %%
print('Good Morning to All')
print('Welcome to Python Programming')
# Out:
# Good Morning to All
# Welcome to Python Programming

# %%
a=10
a
# Out:
# 10

# %%
a1=20
a1
# Out:
# 20

# %%
_1 = 30
_1
# Out:
# 30

# %%
import keyword
# keyword
help(keyword)
keyword
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "graminit.c")
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree after building the interpreter and run:
#
#         ./python Lib/keyword.py
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
#         x.__contains__(y) <==> y in x.
#
# DATA
#     __all__ = ['iskeyword', 'kwlist']
#     kwlist = ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'aw...
#
# FILE
#     c:\users\umohansrinivas\anaconda3\lib\keyword.py
# <module 'keyword' from 'C:\\Users\\umohansrinivas\\anaconda3\\lib\\keyword.py'>

# %% [markdown]
# # Operators
# - Arithmetic Operator
#     - +,-,*,/,%
# - Assignment Operators
#     - =, +=, -=, *=, /=, %=
# - Logical Operators
#     - and, or, not
# - Comparison Operators
#     - ==, >, <
# - Bitwise Operators
# - Membership Operators
# - Identity Operators

# %%
a=25
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 30
# 20
# 125
# 5.0
# 5
# 0

# %%
x=10
y=20.0
print( x and y)
print( x or y)
print(not x)
print(not y)
# Out:
# 20.0
# 10
# False
# False

# %%
x=0
y=20.0
print( x and y)
print( x or y)
print(not x)
print(not y)
# Out:
# 0
# 20.0
# True
# False

# %%
x = False
y = False
x and y
# Out:
# False

# %%
x = False
y = True
x and y
# Out:
# False

# %%
x = True
y = False
x and y
# Out:
# False

# %%
x = True
y = True
x and y
# Out:
# True

# %%
x = False
y = False
x or y
# Out:
# False

# %%
x = False
y = True
x or y
# Out:
# True

# %%
x = True
y = False
x or y
# Out:
# True

# %%
x = True
y = True
x or y
# Out:
# True
